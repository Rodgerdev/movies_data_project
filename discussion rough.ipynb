# %%
import pandas as pd
pd.set_option('display.max_columns',50)

# %%
bom_data = pd.read_csv('bom.movie_gross.csv')
bom_data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
#Add total gross column

# %%
import sqlite3

# %%
conn = sqlite3.connect('im.db')
query_1= "SELECT * FROM movie_basics;"
im_db_data =pd.read_sql(query_1, conn)
conn.close
im_db_data
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
#Remove Original title column
im_db_data.drop(columns='original_title', inplace= True)

# %%
conn = sqlite3.connect('im.db')
query_2= "SELECT * FROM movie_ratings;"
im_db_data2 =pd.read_sql(query_2, conn)
conn.close
im_db_data2
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
#filter more than 50000 votes

# %%
conn = sqlite3.connect('im.db')
query_3= "SELECT * FROM persons;"
im_db_data3 =pd.read_sql(query_3, conn)
conn.close
im_db_data3
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# ...

# %%
conn = sqlite3.connect('im.db')
query_4= "SELECT * FROM directors;"
im_db_data4 =pd.read_sql(query_4, conn)
conn.close
im_db_data4
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %%
#Remove birth and death dates columns
im_db_data3.drop(columns=['birth_year','death_year'], inplace= True)

# %%
conn = sqlite3.connect('im.db')
query_5= "SELECT * FROM known_for;"
im_db_data5 =pd.read_sql(query_5, conn)
conn.close
im_db_data5
# Out:
#          person_id   movie_id
# 0        nm0061671  tt0837562
# 1        nm0061671  tt2398241
# 2        nm0061671  tt0844471
# 3        nm0061671  tt0118553
# 4        nm0061865  tt0896534
# ...            ...        ...
# 1638255  nm9990690  tt9090932
# 1638256  nm9990690  tt8737130
# 1638257  nm9991320  tt8734436
# 1638258  nm9991320  tt9615610
# 1638259  nm9993380  tt8743182
#
# [1638260 rows x 2 columns]

# %%
#find a way to filter actors and actresses

# %%
rt_data = pd.read_csv('rt.movie_info.tsv',sep='\t')

rt_data
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
rt2_data = pd.read_csv('rt.reviews.tsv',sep='\t',encoding='ISO-8859-1')
rt2_data
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
#filter fresh ratings

# %%
rt_merged_df = pd.merge(rt_data, rt2_data, on='id', how='left')
rt_merged_df.head()
# Out:
#    id                                           synopsis rating_x  \
# 0   1  This gritty, fast-paced, and innovative police...        R
# 1   3  New York City, not-too-distant-future: Eric Pa...        R
# 2   3  New York City, not-too-distant-future: Eric Pa...        R
# 3   3  New York City, not-too-distant-future: Eric Pa...        R
# 4   3  New York City, not-too-distant-future: Eric Pa...        R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Science Fiction and Fantasy  David Cronenberg
# 3    Drama|Science Fiction and Fantasy  David Cronenberg
# 4    Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
#Drop synopsis , currency , reviewes, publisher , publish date

# %%
tmdb_data = pd.read_csv('tmdb.movies.csv')
tmdb_data
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
# Match genre ids with genre
# Ensure significant votecount
# Drop Original language & unnamed

# %%
tmdb_data
# Out:
#        Unnamed: 0            genre_ids      id original_language  popularity  \
# 0               0      [12, 14, 10751]   12444                en      33.533
# 1               1  [14, 12, 16, 10751]   10191                en      28.734
# 2               2        [12, 28, 878]   10138                en      28.515
# 3               3      [16, 35, 10751]     862                en      28.005
# 4               4        [28, 878, 12]   27205                en      27.920
# ...           ...                  ...     ...               ...         ...
# 26512       26512             [27, 18]  488143                en       0.600
# 26513       26513             [18, 53]  485975                en       0.600
# 26514       26514         [14, 28, 12]  381231                en       0.600
# 26515       26515      [10751, 12, 28]  366854                en       0.600
# 26516       26516             [53, 27]  309885                en       0.600
#
# ...

# %%
tnmovie_data = pd.read_csv('tn.movie_budgets.csv')
tnmovie_data
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
tnmovie_data.rename(columns={'movie': 'title'},inplace=True)
tnmovie_data
# Out:
#       id  release_date                                        title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
print(im_db_data.head(2))

print(im_db_data2.head(2))
# Out:
#     movie_id                    primary_title  start_year  runtime_minutes  \
# 0  tt0063540                        Sunghursh        2013            175.0
# 1  tt0066787  One Day Before the Rainy Season        2019            114.0
#
#                genres
# 0  Action,Crime,Drama
# 1     Biography,Drama
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559

# %%
# merge on movie id the data from movie basics and review tables
imdb_data = pd.merge(im_db_data,im_db_data2, on='movie_id', how='left')
imdb_data
# Out:
#          movie_id                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
# ...

# %%
# merge on person id the data from persons and director tables(outer join to maintain data from both tables)
merged_df = pd.merge(im_db_data3, im_db_data4, on='person_id', how='outer')
merged_df
# Out:
#         person_id       primary_name  birth_year  death_year  \
# 0       nm0061671  Mary Ellen Bauder         NaN         NaN
# 1       nm0061865       Joseph Bauer         NaN         NaN
# 2       nm0062070         Bruce Baum         NaN         NaN
# 3       nm0062195       Axel Baumann         NaN         NaN
# 4       nm0062798        Pete Baxter         NaN         NaN
# ...           ...                ...         ...         ...
# 788566  nm9993380     Pegasus Envoyé         NaN         NaN
# 788567  nm9993380     Pegasus Envoyé         NaN         NaN
# 788568  nm3754088                NaN         NaN         NaN
# 788569  nm3754088                NaN         NaN         NaN
# 788570  nm9326757                NaN         NaN         NaN
#
#                                       primary_profession   movie_id
# 0              miscellaneous,production_manager,producer        NaN
# 1             composer,music_department,sound_department        NaN
# ...

# %%
# merge on person id the data from persons,directors and knownfor tables
merged_df2 = pd.merge(merged_df, im_db_data5, on='person_id', how='outer')
merged_df2
# Out:
#          person_id       primary_name  birth_year  death_year  \
# 0        nm0061671  Mary Ellen Bauder         NaN         NaN
# 1        nm0061671  Mary Ellen Bauder         NaN         NaN
# 2        nm0061671  Mary Ellen Bauder         NaN         NaN
# 3        nm0061671  Mary Ellen Bauder         NaN         NaN
# 4        nm0061865       Joseph Bauer         NaN         NaN
# ...            ...                ...         ...         ...
# 2328987  nm9993380     Pegasus Envoyé         NaN         NaN
# 2328988  nm9993380     Pegasus Envoyé         NaN         NaN
# 2328989  nm3754088                NaN         NaN         NaN
# 2328990  nm3754088                NaN         NaN         NaN
# 2328991  nm9326757                NaN         NaN         NaN
#
#                                  primary_profession movie_id_x movie_id_y
# 0         miscellaneous,production_manager,producer        NaN  tt0837562
# ...

# %%
merged_df2.rename(columns={'movie_id_y':'movie_id'},inplace=True)

# %%
merged_df2

# %%
merged_df3_imdb = pd.merge(imdb_data, merged_df2, on='movie_id', how='left')
merged_df3_imdb
# Out:
#           movie_id                    primary_title  start_year  \
# 0        tt0063540                        Sunghursh        2013
# 1        tt0063540                        Sunghursh        2013
# 2        tt0066787  One Day Before the Rainy Season        2019
# 3        tt0069049       The Other Side of the Wind        2018
# 4        tt0069049       The Other Side of the Wind        2018
# ...            ...                              ...         ...
# 1137684  tt9916754   Chico Albuquerque - Revelações        2013
# 1137685  tt9916754   Chico Albuquerque - Revelações        2013
# 1137686  tt9916754   Chico Albuquerque - Revelações        2013
# 1137687  tt9916754   Chico Albuquerque - Revelações        2013
# 1137688  tt9916754   Chico Albuquerque - Revelações        2013
#
#          runtime_minutes              genres  averagerating  numvotes  \
# 0                  175.0  Action,Crime,Drama            7.0      77.0
# ...

# %%
merged_df3_copy = merged_df3.copy()
merged_df3_copy.columns
# Out:
# Index(['movie_id', 'primary_title', 'start_year', 'runtime_minutes', 'genres',
#        'averagerating', 'numvotes', 'person_id', 'primary_name', 'birth_year',
#        'death_year', 'primary_profession', 'movie_id_x'],
#       dtype='object')

# %%
rt_merged_df.head()
# Out:
#    id                                           synopsis rating_x  \
# 0   1  This gritty, fast-paced, and innovative police...        R
# 1   3  New York City, not-too-distant-future: Eric Pa...        R
# 2   3  New York City, not-too-distant-future: Eric Pa...        R
# 3   3  New York City, not-too-distant-future: Eric Pa...        R
# 4   3  New York City, not-too-distant-future: Eric Pa...        R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Science Fiction and Fantasy  David Cronenberg
# 3    Drama|Science Fiction and Fantasy  David Cronenberg
# 4    Drama|Science Fiction and Fantasy  David Cronenberg
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
tnmovie_data
# Out:
#       id  release_date                                        title  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
bom_data
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
merged_df3_copy.describe().T
# Out:
#                      count          mean           std     min         25%  \
# runtime_minutes   116326.0  8.634854e+01  1.650042e+02     1.0      70.000
# averagerating      76360.0  6.319696e+00  1.468087e+00     1.0       5.400
# numvotes           76360.0  4.198917e+03  3.279312e+04     5.0      15.000
# domestic_gross_x    4183.0  3.047574e+07  6.692315e+07   100.0  138000.000
# year                4221.0  2.014230e+03  2.420222e+00  2010.0    2012.000
# Unnamed: 0         23848.0  1.352837e+04  7.488954e+03     0.0    7214.500
# id_x               23848.0  2.887661e+05  1.487364e+05   189.0  157026.500
# popularity         23848.0  3.856712e+00  4.915146e+00     0.6       0.655
# vote_average       23848.0  5.810454e+00  1.710159e+00     0.0       5.000
# vote_count         23848.0  2.821661e+02  1.126536e+03     1.0       2.000
# id_y                5275.0  5.108398e+01  2.738425e+01     1.0      29.000
#
#                           50%           75%           max
# ...

# %%
merged_df3_copy.isna().sum()
# Out:
# movie_id                  0
# title                     0
# runtime_minutes       28996
# genres                    0
# averagerating         68962
# numvotes              68962
# studio               141104
# domestic_gross_x     141139
# foreign_gross        142780
# year                 141101
# Unnamed: 0           121474
# genre_ids            121474
# id_x                 121474
# original_language    121474
# popularity           121474
# release_date_x       121474
# vote_average         121474
# vote_count           121474
# id_y                 140047
# release_date_y       140047
# production_budget    140047
# domestic_gross_y     140047
# worldwide_gross      140047
# dtype: int64
